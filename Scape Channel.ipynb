onQM5lj3hr89AY492HKhDCH6-1UKl0pTUnBNZnql4GvFtmawg; NID=511=nJwyJCSLbsEXfdRLGEeK0oL2XrIocQwAE8i0A8wPuaR0q_a-DXPQp8ackWK3BohvpBl4jvhuCLYLirSFc8Uafj8z3yc48lvUo9z0APdGB4mEKc2Nlv_drBfC-1rFh041yvzuMDCDhDUa4ZOgj5jglSnlHvY306Y0nWQ3HF-3Yj1Jmx16MN1QgGMiSETouFzm2ZBMtvABsMQIwE743wI-FeqUJVu3fqLPUdqwWcJWYBhvBtYDheiR1QiCJEaIDvxWr80wLpeLg-C7cHkvHDTP1kIZx9XZA2CFvMFYXa264iJokoHcxY4d4ErzMsGPbiobFO5Fyg; 1P_JAR=2023-05-18-23; GOOGLE_ABUSE_EXEMPTION=ID=3848956767e0bfef:TM=1684453110:C=r:IP=2409:40e3:104f:3dff:81cb:c003:c198:eda8-:S=tPX6UV2ycL1ZJNrbVhG6xJ4; DV=cwOtsJAWco9RgEd9jfKlQS4EXqsTg5ipaiyffETzdAIAAODb1J3c88oZDQEAAPCSFA-qpoSSQgAAAFXO0QKIuui4EQAAAA; SIDCC=AP8dLtwyHK-KM_XLdFPc8dvEX6OEjDTMukJobo07OuzpFdjXYj04ljwBmZ51EY2c6oTmiTVExd8; __Secure-1PSIDCC=AP8dLtz9gxNuG3MmvFhvvPnWWOJYy3WTRxvRKc18rZRAtuntZ4mRVucvSdZBaVVmFOkamCBpThY; __Secure-3PSIDCC=AP8dLtzrXlIP-CU8QS948FSc8H3IGho7TjEwoFeUj87YgypP6yLfZ5e29I5z9t5LjkVDi580Pdst',
    'dnt': '1',
    'referer': 'https://www.google.com/',
    'sec-ch-ua': '"Google Chrome";v="113", "Chromium";v="113", "Not-A.Brand";v="24"',
    'sec-ch-ua-arch': '"x86"',
    'sec-ch-ua-bitness': '"64"',
    'sec-ch-ua-full-version': '"113.0.5672.126"',
    'sec-ch-ua-full-version-list': '"Google Chrome";v="113.0.5672.126", "Chromium";v="113.0.5672.126", "Not-A.Brand";v="24.0.0.0"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-model': '""',
    'sec-ch-ua-platform': '"Windows"',
    'sec-ch-ua-platform-version': '"15.0.0"',
    'sec-ch-ua-wow64': '?0',
    'sec-fetch-dest': 'document',
    'sec-fetch-mode': 'navigate',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-user': '?1',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/113.0.0.0 Safari/537.36',
    'x-client-data': 'CJK2yQEIpLbJAQipncoBCJCWywEIk6HLAQid/swBCLSUzQEI0JrNAQiFoM0BCNKizQEIn6TNAQiPps0BCKSqzQEIwKrNAQjeq80BCIWxzQEIvrHNAQjvs80BCKCErQIYiqfNAQ==',
}

# %%
import requests
from bs4 import BeautifulSoup
import csv
import json
import re

# %%
def scrape_google_results(search_query, num_results,cookies,headers):
    start=0
    links=[]
    channel=[]
    for i in range(0,10):
        url=f"https://www.google.com/search?q={search_query}&num={num_results}&sxsrf=APwXEdenbbYEP7byNfEQ5B3EkMncTG_ZYA:1684348406647&ei=9h1lZLaPJ8iN4-EPj9qI2Aw&start={start}&sa=N&filter=0&ved=2ahUKEwi24tLj_vz-AhXIxjgGHQ8tAss4rAIQ8tMDegQIBRAE&biw=978&bih=714&dpr=1.25"
        response = requests.get(
            url=url,
            cookies=cookies,
            headers=headers,
        )
        print(response)
        soup = BeautifulSoup(response.text, 'html.parser')
        results = soup.find_all('div', {'class': 'DhN8Cf'})
        # channel_result=soup.find_all('div', {'class': 'P7xzyf'})
        # text = channel_result.find_all(text=True, recursive=False)
        # print(text)
        # text = ' '.join(text).strip()
        # print(text)
        div = soup.find_all('div', class_='P7xzyf')
        # Extract the desired text
        for ele in div:
            p=str(ele)
            cha=p.split(" · ")[1]
            s= BeautifulSoup(cha, 'html.parser')
            f = s.find('span').text
            f=re.sub(r'[^A-Za-z]', '', f)
            link="https://www.youtube.com/@"+f
            channel.append(link)
            # text = div_element.find_all(text=True, recursive=False)
            # print(text)
            # text = ' '.join(text).strip()
            # print(text)
        # print(channel_result)
        # print(results)

        for result in results:
            link = result.find('a')['href']
            if "youtube.com" in link:
                links.append(link)
        start+=100

    return links,channel

# %%
def save_links_to_csv(links):
    with open('youtube_link.csv', 'w', newline='', encoding='utf-8') as file:
        writer = csv.writer(file)
        writer.writerow(['YouTube Channel Links'])
        writer.writerows([[link] for link in links])

def save_channel_to_csv(links):
    with open('youtube_channels.csv', 'w', newline='', encoding='utf-8') as file:
        writer = csv.writer(file)
        writer.writerow(['YouTube Channel Links'])
        writer.writerows([[link] for link in links])

def save_links_to_json(links):
    data = {'YouTube Channel Links': links}
    with open('youtube_link.json', 'w', encoding='utf-8') as file:
        json.dump(data, file, indent=4)

# %%
if __name__ == "__main__":
    search_query = "site:youtube.com openinapp.co"
    num_results = 10000

    # Scrape Google search results
    links,channels = scrape_google_results(search_query, num_results,cookies,headers)

    # Save links to CSV file
    save_links_to_csv(links)

    save_channel_to_csv(channels)
    # Save links to JSON file
    save_links_to_json(links)

    print(f"Scraped {len(links)} YouTube links and saved to 'youtube_link.csv' and 'youtube_link.json' files.")
    print(f"Scraped {len(channels)} YouTube channel links and saved to 'youtube_channels.csv' file.")
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# Scraped 374 YouTube links and saved to 'youtube_link.csv' and 'youtube_link.json' files.
# Scraped 374 YouTube channel links and saved to 'youtube_channels.csv' file.
